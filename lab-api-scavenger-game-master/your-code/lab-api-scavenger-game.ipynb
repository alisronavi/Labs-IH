# %%
import os
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
cwd = os.getcwd()
cwd
# Out:
# '/Users/alanromero/IH/Challenges/Semana_3/lab-api-scavenger-game-master/your-code'

# %%
data_forks = requests.get('https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks')
data_forks
# Out:
# <Response [200]>

# %%
data_forks = data_forks.json()
df_forks = pd.DataFrame(data_forks) 
df_forks
# Out:
#            id                           node_id               name  \
# 0   487632383                      R_kgDOHRCt_w       mad-oct-2018
# 1   485472962                      R_kgDOHO-6wg       mad-oct-2018
# 2   416830289                      R_kgDOGNhTUQ       mad-oct-2018
# 3   357335874  MDEwOlJlcG9zaXRvcnkzNTczMzU4NzQ=       mad-oct-2018
# 4   335309218  MDEwOlJlcG9zaXRvcnkzMzUzMDkyMTg=       mad-oct-2018
# 5   220066216  MDEwOlJlcG9zaXRvcnkyMjAwNjYyMTY=       mad-oct-2018
# 6   204100911  MDEwOlJlcG9zaXRvcnkyMDQxMDA5MTE=       mad-oct-2018
# 7   200138127  MDEwOlJlcG9zaXRvcnkyMDAxMzgxMjc=       mad-oct-2018
# 8   198273438  MDEwOlJlcG9zaXRvcnkxOTgyNzM0Mzg=       mad-oct-2018
# 9   167001044  MDEwOlJlcG9zaXRvcnkxNjcwMDEwNDQ=        datamad0119
# 10  162498469  MDEwOlJlcG9zaXRvcnkxNjI0OTg0Njk=    madrid-oct-2018
# 11  154625001  MDEwOlJlcG9zaXRvcnkxNTQ2MjUwMDE=    madrid-oct-2018
# 12  154291113  MDEwOlJlcG9zaXRvcnkxNTQyOTExMTM=  Ironhack-oct-2018
# ...

# %%
list(df_forks['language'].drop_duplicates())
# Out:
# [None, 'Jupyter Notebook', 'HTML']

# %%
df_forks.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
data_commits = requests.get('https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/commits')
data_commits = data_commits.json()
flattered_commits = json_normalize(data_commits)
flattered_commits
# Out:
# /var/folders/8p/70rg96_90177mq050h9mr8d80000gn/T/ipykernel_24156/2006380791.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   flattered_commits = json_normalize(data_commits)
#                                          sha  \
# 0   1638e5506e6947b77bfe78761d345476ae80d017
# 1   f332b5e6fcea965dc80f62220d7ee1457b04b90d
# 2   4c048c3efc18cf9d50e34c76919c8049ee7f2dbd
# 3   41e09d4fbf64bacb2fdfe7d90cdd0cd71bd24310
# 4   750eb91e4535c14ec4bf03f60cb5756a1c93f68f
# 5   4a8cc3cb64821cb58182a3a94be38f17d27a8e8f
# 6   1501bac01f8183d223a47ca7f23649a5d98d7e00
# 7   6c2a1247d4e13a37261081279f250ffa82ed5c96
# 8   cc02db3df76c8a16ecee3f7a937366ff427a7c3a
# 9   49ba929952728ab17635591cf55137c8af01babb
# 10  ba93368ee5593b15c7b1829f82cbacb9a003476c
# 11  2034c389cb81f30d30f94acc2a5237377d387dc1
# 12  09cf3f0163fe3895128cb322f5450672435ede7e
# 13  825dea0b3aab60bf587130441fab30d8abab775c
# 14  ced5e055e9313f60c57a7daab4ee89eac9f2c409
# ...

# %%
flattered_commits['committer.type'].value_counts()
# Out:
# User    30
# Name: committer.type, dtype: int64

# %%
joke = requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger/git/trees/master?recursive=1')
joke
# Out:
# <Response [200]>

# %%
joke = joke.json()
df_joke = pd.DataFrame(joke)
df_joke
# Out:
#                                           sha  \
# 0    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 1    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 2    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 3    9308ccc8a4c34c5e3a991ee815222a9691c32476
# 4    9308ccc8a4c34c5e3a991ee815222a9691c32476
# ..                                        ...
# 104  9308ccc8a4c34c5e3a991ee815222a9691c32476
# 105  9308ccc8a4c34c5e3a991ee815222a9691c32476
# 106  9308ccc8a4c34c5e3a991ee815222a9691c32476
# 107  9308ccc8a4c34c5e3a991ee815222a9691c32476
# 108  9308ccc8a4c34c5e3a991ee815222a9691c32476
#
#                                                    url  \
# 0    https://api.github.com/repos/ironhack-datalabs...
# 1    https://api.github.com/repos/ironhack-datalabs...
# 2    https://api.github.com/repos/ironhack-datalabs...
# 3    https://api.github.com/repos/ironhack-datalabs...
# 4    https://api.github.com/repos/ironhack-datalabs...
# ..                                                 ...
# ...
